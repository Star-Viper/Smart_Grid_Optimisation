# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/combined_data.csv')

# %%
df.head()
# Out:
#                   DateTime  Wind speed | (m/s)_x  \
# 0  2019-01-01 01:00:00.000                10.926
# 1  2019-01-01 02:00:00.000                 9.919
# 2  2019-01-01 03:00:00.005                 8.567
# 3  2019-01-01 04:00:00.010                 7.877
# 4  2019-01-01 05:00:00.015                 7.259
#
#    Power generated by system | (MW)  Air temperature | (°C)  \
# 0                            10.926                  10.926
# 1                             9.919                   9.919
# 2                             8.567                   8.567
# 3                             7.877                   7.877
# 4                             7.259                   7.259
#
#    Wind speed | (m/s)_y
# 0                10.926
# 1                 9.919
# 2                 8.567
# 3                 7.877
# 4                 7.259

# %%
df.columns
# Out:
# Index(['DateTime', 'Wind speed | (m/s)_x', 'Power generated by system | (MW)',
#        'Air temperature | (°C)', 'Wind speed | (m/s)_y'],
#       dtype='object')

# %%
test_df = pd.read_excel("/content/wind_power_gen_3months_validation_data.xlsx")

# %%
test_df.head()
# Out:
#              DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0 2024-01-01 00:00:00                   6.609          0.988077
# 1 2024-01-01 01:00:00                   5.257          0.988969
# 2 2024-01-01 02:00:00                   4.374          0.989708
# 3 2024-01-01 03:00:00                   2.913          0.990171
# 4 2024-01-01 04:00:00                   1.152          0.990264
#
#    Wind speed | (m/s)  Power generated by system | (MW)
# 0              10.868                           53.1810
# 1              10.679                           51.9083
# 2              11.200                           56.3540
# 3              10.962                           54.9368
# 4              11.307                           57.7431

# %%
df.shape
# Out:
# (43823, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43823 entries, 0 to 43822
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   DateTime                          43823 non-null  object
#  1   Wind speed | (m/s)_x              43823 non-null  float64
#  2   Power generated by system | (MW)  43823 non-null  float64
#  3   Air temperature | (°C)            43823 non-null  float64
#  4   Wind speed | (m/s)_y              43823 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#                   DateTime  Wind speed | (m/s)_x  \
# 0  2019-01-01 01:00:00.000                10.926
# 1  2019-01-01 02:00:00.000                 9.919
# 2  2019-01-01 03:00:00.005                 8.567
# 3  2019-01-01 04:00:00.010                 7.877
# 4  2019-01-01 05:00:00.015                 7.259
#
#    Power generated by system | (MW)  Air temperature | (°C)  \
# 0                            10.926                  10.926
# 1                             9.919                   9.919
# 2                             8.567                   8.567
# 3                             7.877                   7.877
# 4                             7.259                   7.259
#
#    Wind speed | (m/s)_y
# 0                10.926
# 1                 9.919
# 2                 8.567
# 3                 7.877
# 4                 7.259

# %%
df.iloc[20000:20005,:]
# Out:
#                   DateTime  Wind speed | (m/s)_x  \
# 20000  2021-04-13 09:00:00                12.656
# 20001  2021-04-13 10:00:00                11.877
# 20002  2021-04-13 11:00:00                10.720
# 20003  2021-04-13 12:00:00                 9.529
# 20004  2021-04-13 13:00:00                 8.994
#
#        Power generated by system | (MW)  Air temperature | (°C)  \
# 20000                            12.656                  12.656
# 20001                            11.877                  11.877
# 20002                            10.720                  10.720
# 20003                             9.529                   9.529
# 20004                             8.994                   8.994
#
#        Wind speed | (m/s)_y
# 20000                12.656
# 20001                11.877
# 20002                10.720
# 20003                 9.529
# 20004                 8.994

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43823 entries, 0 to 43822
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   DateTime                          43823 non-null  object
#  1   Wind speed | (m/s)_x              43823 non-null  float64
#  2   Power generated by system | (MW)  43823 non-null  float64
#  3   Air temperature | (°C)            43823 non-null  float64
#  4   Wind speed | (m/s)_y              43823 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.7+ MB

# %%
df.columns
# Out:
# Index(['DateTime', 'Wind speed | (m/s)_x', 'Power generated by system | (MW)',
#        'Air temperature | (°C)', 'Wind speed | (m/s)_y'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['DateTime', 'Air temperature | (°C)', 'Pressure | (atm)',
#        'Wind speed | (m/s)', 'Power generated by system | (MW)'],
#       dtype='object')

# %%
ok = pd.read_excel('/content/Power_predicted_values.')

# %%
print(df.columns)
# Out:
# Index(['DateTime', 'Wind speed | (m/s)_x', 'Power generated by system | (MW)',
#        'Air temperature | (°C)', 'Wind speed | (m/s)_y'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X = df.drop(['DateTime','Power generated by system | (MW)'],axis=1)
y = df['Power generated by system | (MW)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = RandomForestRegressor(n_estimators=100, random_state=42)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print(f"Mean squared error: {mse}")
# Out:
# Mean squared error: 2.2732035346464435e-05

# %%
model
# Out:
# RandomForestRegressor(random_state=42)

# %%
test_df.columns
# Out:
# Index(['DateTime', 'Air temperature | (°C)', 'Pressure | (atm)',
#        'Wind speed | (m/s)', 'Power generated by system | (MW)'],
#       dtype='object')

# %%
pf = pd.read_csv('/content/Power_predicted_values.csv')

# %%
pf.head()
# Out:
#               DateTime  Power_predicted_values
# 0  2024-01-01 03:00:00               53.097370
# 1  2024-01-01 04:00:00               51.866920
# 2  2024-01-01 05:00:00               54.469070
# 3  2024-01-01 06:00:00               54.235924
# 4  2024-01-01 07:00:00               57.192543

# %%
test_df.head()
# Out:
#              DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0 2024-01-01 00:00:00                   6.609          0.988077
# 1 2024-01-01 01:00:00                   5.257          0.988969
# 2 2024-01-01 02:00:00                   4.374          0.989708
# 3 2024-01-01 03:00:00                   2.913          0.990171
# 4 2024-01-01 04:00:00                   1.152          0.990264
#
#    Wind speed | (m/s)  Power generated by system | (MW)
# 0              10.868                           53.1810
# 1              10.679                           51.9083
# 2              11.200                           56.3540
# 3              10.962                           54.9368
# 4              11.307                           57.7431
